# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel('../data/shibor.xlsx')

# %%
dic = {'SHIBOR overnight': 'M0017138',
       'SHIBOR 3M': 'M0017142'
      }

# %%
(df[dic['SHIBOR 3M']] - df[dic['SHIBOR overnight']]).plot(figsize=(16, 9))
