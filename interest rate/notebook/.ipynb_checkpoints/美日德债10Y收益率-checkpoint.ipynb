# %%
import pandas as pd
import numpy as np
from WindPy import w
import matplotlib.pyplot as plt
import datetime
# %matplotlib inline

# %%
w.start()
# Out:
# Welcome to use Wind Quant API for Python (WindPy)!
#
# COPYRIGHT (C) 2017 WIND INFORMATION CO., LTD. ALL RIGHTS RESERVED.
# IN NO CIRCUMSTANCE SHALL WIND BE RESPONSIBLE FOR ANY DAMAGES OR LOSSES CAUSED BY USING WIND QUANT API FOR Python.
# .ErrorCode=0
# .Data=[OK!]

# %%
codes = 'G0000891,G0008068,G1235664'

# %%
data = w.edb(codes, '1997-09-01', datetime.date.today())

# %%
df = pd.DataFrame(np.array(data.Data).T, index=data.Times, columns=[u'美国', u'德国', u'日本'])

# %%
df = df.fillna(method='ffill')

# %%
df.tail()
# Out:
#               美国    德国     日本
# 2019-03-28  2.39 -0.08 -0.086
# 2019-03-29  2.41 -0.07 -0.082
# 2019-04-01  2.49 -0.05 -0.070
# 2019-04-02  2.48 -0.05 -0.053
# 2019-04-03  2.52 -0.01 -0.053

# %%
fig, ax = plt.subplots(figsize=(16, 9))

lns1 = ax.plot(df[u'美国'], color='blue', label=u'美国')
lns2 = ax.plot(df[u'德国'], color='red', label=u'德国')
lns3 = ax.plot(df[u'日本'], color='black', label=u'日本')

# zero line
ax.axhline(y=0, color='black', linewidth=1)

# Legend
lns = lns1 + lns2 + lns3
labs = [l.get_label() for l in lns]
ax.legend(lns, labs, frameon=False, fontsize=15, loc='upper center', ncol=3, bbox_to_anchor=(0.5, 1))

# Axis
ax.yaxis.tick_right()
ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)
vals = ax.get_yticks()
ax.set_yticklabels(['{:2.2f}%'.format(x) for x in vals])

# Title
_ = ax.set_title(u'美德日10Y国债收益率', fontsize=25, y=1.02)
fig.savefig(u'../pic/美德日10Y国债收益率.jpg', format='jpg', dpi=200, bbox_inches='tight')
