# %% [markdown]
# # M2与名义GDP增速差与股市的关系
#
# M2相对名义GDP增速高则说明市场资金风险偏好低，股市估值应该提升，反之估值应该下降

# %%
from WindPy import w
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
w.start()
# Out:
# Welcome to use Wind Quant API for Python (WindPy)!
#
# COPYRIGHT (C) 2017 WIND INFORMATION CO., LTD. ALL RIGHTS RESERVED.
# IN NO CIRCUMSTANCE SHALL WIND BE RESPONSIBLE FOR ANY DAMAGES OR LOSSES CAUSED BY USING WIND QUANT API FOR Python.
# .ErrorCode=0
# .Data=[OK!]

# %% [markdown]
# # 获取M2与GDP数据

# %%
data = w.edb("M0001385,M6347627", '2000-01-01', '2018-10-10')

# %%
df = pd.DataFrame(np.array(data.Data).T, index=data.Times, columns=['M2', 'GDP'])

# %%
df.to_excel('../data/M2-GDP.xlsx')

# %%
df = pd.read_excel('../data/M2-GDP.xlsx', index_col=0)

# %%
df = df.fillna(method='ffill').dropna()

# %%
df.tail()
# Out:
#              M2    GDP
# 2018-04-30  8.3  10.02
# 2018-05-31  8.3  10.02
# 2018-06-30  8.0   9.82
# 2018-07-31  8.5   9.82
# 2018-08-31  8.2   9.82

# %%
diff = df['M2'] - df['GDP']

# %% [markdown]
# # 获取股票市盈率

# %%
data = w.wsd('881001.WI', 'pe_ttm,pb_lf', '2000-01-01', '2018-10-10')

# %%
val = pd.DataFrame(np.array(data.Data).T, index=data.Times, columns=['pe', 'pb'])

# %%
val.index = pd.to_datetime(val.index)

# %%
val = val.resample('M').last()

# %% [markdown]
# # 画图展示

# %%
fig, ax = plt.subplots(figsize=(16, 9))
# ax.plot(val['pe'], color='blue', label=u'市盈率')
ax.plot(val['pb'], color='blue', label=u'市净率')
ax.legend()
ax1 = ax.twinx()
ax1.bar(diff.index, diff, label=u'M2与名义GDP增速差', color='red', width=10)
ax1.legend(loc='upper left')
