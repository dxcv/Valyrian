# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel('../data/BDI.xlsx')

# %%
df.head()
# Out:
#             波罗的海干散货指数(BDI)
# 2014-02-28            1258
# 2014-03-03            1276
# 2014-03-04            1325
# 2014-03-05            1391
# 2014-03-06            1480

# %%
imp = pd.read_excel(u'../data/中国进口金额累计同比.xlsx')

# %%
imp.head()
# Out:
#             中国:进口金额:累计同比
# 2014-02-28         -13.2
# 2014-03-31         -22.9
# 2014-04-30         -23.3
# 2014-05-31         -18.9
# 2014-06-30         -14.8

# %%
fig, ax = plt.subplots(figsize=(16, 9))

lns1 = ax.plot(imp[u'中国:进口金额:累计同比'], color='blue', label=u'中国进口同比增速')

# zero line
ax.axhline(y=0, color='black', linewidth=1)

# Legend
lns = lns1
labs = [l.get_label() for l in lns]
ax.legend(lns, labs, frameon=False, fontsize=15, loc='upper center', ncol=3, bbox_to_anchor=(0.5, 1))

# Axis
ax.yaxis.tick_right()
ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)
vals = ax.get_yticks()
ax.set_yticklabels(['{:2.0f}%'.format(x) for x in vals])


# Title
_ = ax.set_title(u'中国进口金额', fontsize=25, y=1.02)

# %%
fig, ax = plt.subplots(figsize=(16, 9))

lns1 = ax.plot(df[df.index <= '2019-01-01'][u'波罗的海干散货指数(BDI)'], color='blue', label='BDI')
lns2 = ax.plot(df[df.index > '2019-01-01'][u'波罗的海干散货指数(BDI)'], color='blue', linestyle='--', label=u'今年BDI')
axx = ax.twinx()
lns3 = axx.plot(imp[u'中国:进口金额:累计同比'], color='red', label=u'中国进口同比增速')

# zero line
axx.axhline(y=0, color='black', linewidth=1)

# Legend
lns = lns1 + lns2 + lns3
labs = [l.get_label() for l in lns]
ax.legend(lns, labs, frameon=False, fontsize=15, loc='upper center', ncol=3, bbox_to_anchor=(0.5, 1))

# Axis
ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)
axx.yaxis.set_tick_params(labelsize=15)
vals = ax.get_yticks()
ax.set_yticklabels(['{:2.0f}'.format(x) for x in vals], color='blue')
vals = axx.get_yticks()
axx.set_yticklabels(['{:3.0f}%'.format(x) for x in vals], color='red')


# Title
_ = ax.set_title(u'波罗的海干散货指数(BDI)', fontsize=25, y=1.05)
fig.savefig('../pic/bdi.jpg', format='jpg', dpi=200, bbox_inches='tight')
