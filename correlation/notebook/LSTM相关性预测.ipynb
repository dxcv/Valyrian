# %% [markdown]
# # LSTM相关性预测

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.models import Sequential
import datetime
# %matplotlib inline

# %% [markdown]
# ## 读取波动率序列

# %%
np.random.seed(1234)
seq_len = 20

# %%
fname = '../../risk parity portfolio/data/assets.xlsx'
df = pd.read_excel(fname)
# df.sort_index(inplace=True, ascending=False)
vec = df['881001.WI'].pct_change().rolling(window=243).corr(df['CBA00101.CS'].pct_change())
vec = vec[vec.index >= '2009-01-01']
vec.tail()
# Out:
# 2019-02-28   -0.187005
# 2019-03-01   -0.190906
# 2019-03-04   -0.194645
# 2019-03-05   -0.197840
# 2019-03-06   -0.199515
# dtype: float64

# %%
fig, ax = plt.subplots(figsize=(16, 9))
ax.plot(vec, label=u'相关性')
ax.legend()

# %% [markdown]
# ## 将序列转成矩阵
# 横坐标是样本点的个数，纵坐标是窗口大小

# %%
def series2matrix(vec, seq_len):
    matrix = []
    for i in range(vec.size - seq_len + 1):
        matrix.append(vec[i : i+seq_len])
    return np.array(matrix)

# %%
mat = series2matrix(vec, seq_len)

# %%
fig, ax = plt.subplots(figsize=(16, 9))
ax.plot(mat[:, -1], label=u'相关性')
ax.legend()

# %% [markdown]
# ## 序列预处理

# %%
# shift all data by mean
# shifted_value = mat.mean()
# mat -= shifted_value

# %% [markdown]
# ## 得到训练和测试样本

# %%
# split dataset: 90% for training and 10% for testing
train_row = int(round(0.9 * mat.shape[0]))
train_set = mat[:train_row, :].copy()
train_mean = train_set.mean(axis=1).reshape(-1, 1).copy()
train_set -= train_mean
test_set = mat[train_row:, :].copy()
test_mean = test_set.mean(axis=1).reshape(-1, 1).copy()
test_set -= test_mean

# %%
fig, ax = plt.subplots(figsize=(16, 9))
ax.plot((train_set + train_mean)[:, -1], label=u'相关性')
# ax.plot((test_set + test_mean)[:, -1], label=u'波动率')
ax.legend()

# %%
# shuffle the training set (but do not shuffle the test set)
np.random.shuffle(train_set)
# the training set
X_train = train_set[:, :-1]
# the last column is the true value to compute the mean-squared-error loss
y_train = train_set[:, -1] 
# the test set
X_test = test_set[:, :-1]
y_test = test_set[:, -1]

# %%
# the input to LSTM layer needs to have the shape of (number of samples, the dimension of each element)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (2208, 19, 1)
# (245, 19, 1)

# %% [markdown]
# ## 构建模型

# %%
# build the model
model = Sequential()

# %%
# layer 1: LSTM
model.add(LSTM(input_shape=(None,1), units=50, return_sequences=True))
model.add(Dropout(0.2))

# %%
# layer 2: LSTM
model.add(LSTM(units=100, return_sequences=False))
model.add(Dropout(0.2))

# %%
# layer 3: dense
# linear activation: a(x) = x
model.add(Dense(units=1, activation='linear'))

# %%
# compile the model
model.compile(loss="mse", optimizer="rmsprop")

# %% [markdown]
# ## 训练模型

# %%
# train the model
model.fit(X_train, y_train, batch_size=512, epochs=50, validation_split=0.05, verbose=1)
# Out:
# Train on 2097 samples, validate on 111 samples
# Epoch 1/50
# 2097/2097 [==============================] - 3s 1ms/step - loss: 7.0636e-04 - val_loss: 2.7894e-04
# Epoch 2/50
# 2097/2097 [==============================] - 1s 247us/step - loss: 3.4172e-04 - val_loss: 2.5096e-04
# Epoch 3/50
# 2097/2097 [==============================] - 1s 261us/step - loss: 3.0136e-04 - val_loss: 2.2856e-04
# Epoch 4/50
# 2097/2097 [==============================] - 0s 234us/step - loss: 3.0196e-04 - val_loss: 2.0417e-04
# Epoch 5/50
# 2097/2097 [==============================] - 1s 240us/step - loss: 2.3614e-04 - val_loss: 2.0531e-04
# Epoch 6/50
# 2097/2097 [==============================] - 1s 255us/step - loss: 2.7190e-04 - val_loss: 1.8147e-04
# Epoch 7/50
# 2097/2097 [==============================] - 1s 281us/step - loss: 1.7414e-04 - val_loss: 1.4701e-04
# Epoch 8/50
# 2097/2097 [==============================] - 1s 274us/step - loss: 1.8714e-04 - val_loss: 1.2990e-04
# Epoch 9/50
# 2097/2097 [==============================] - 1s 278us/step - loss: 1.4497e-04 - val_loss: 1.8008e-04
# Epoch 10/50
# 2097/2097 [==============================] - 1s 282us/step - loss: 1.8599e-04 - val_loss: 1.1824e-04
# Epoch 11/50
# 2097/2097 [==============================] - 1s 284us/step - loss: 1.3180e-04 - val_loss: 2.6580e-04
# Epoch 12/50
# 2097/2097 [==============================] - 1s 247us/step - loss: 2.1246e-04 - val_loss: 1.1560e-04
# Epoch 13/50
# 2097/2097 [==============================] - 1s 241us/step - loss: 1.3127e-04 - val_loss: 1.0735e-04
# Epoch 14/50
# 2097/2097 [==============================] - 1s 257us/step - loss: 1.2513e-04 - val_loss: 1.1360e-04
# Epoch 15/50
# 2097/2097 [==============================] - 1s 259us/step - loss: 1.5398e-04 - val_loss: 1.1203e-04
# Epoch 16/50
# 2097/2097 [==============================] - 1s 264us/step - loss: 1.2841e-04 - val_loss: 9.6497e-05
# Epoch 17/50
# 2097/2097 [==============================] - 1s 257us/step - loss: 1.2176e-04 - val_loss: 1.3419e-04
# Epoch 18/50
# 2097/2097 [==============================] - 1s 270us/step - loss: 1.4077e-04 - val_loss: 1.6142e-04
# Epoch 19/50
# 2097/2097 [==============================] - 0s 233us/step - loss: 1.7182e-04 - val_loss: 9.1439e-05
# Epoch 20/50
# 2097/2097 [==============================] - 0s 238us/step - loss: 1.0863e-04 - val_loss: 9.6107e-05
# Epoch 21/50
# 2097/2097 [==============================] - 1s 241us/step - loss: 1.1225e-04 - val_loss: 9.7694e-05
# Epoch 22/50
# 2097/2097 [==============================] - 1s 239us/step - loss: 1.0817e-04 - val_loss: 8.4912e-05
# Epoch 23/50
# 2097/2097 [==============================] - 0s 236us/step - loss: 1.3214e-04 - val_loss: 1.0808e-04
# Epoch 24/50
# 2097/2097 [==============================] - 0s 238us/step - loss: 1.1054e-04 - val_loss: 8.1838e-05
# Epoch 25/50
# 2097/2097 [==============================] - 0s 236us/step - loss: 1.1276e-04 - val_loss: 9.2073e-05
# Epoch 26/50
# 2097/2097 [==============================] - 0s 231us/step - loss: 1.0023e-04 - val_loss: 1.0766e-04
# Epoch 27/50
# 2097/2097 [==============================] - 1s 242us/step - loss: 1.2348e-04 - val_loss: 7.6149e-05
# Epoch 28/50
# 2097/2097 [==============================] - 1s 242us/step - loss: 9.3394e-05 - val_loss: 1.0772e-04
# Epoch 29/50
# 2097/2097 [==============================] - 0s 235us/step - loss: 9.6134e-05 - val_loss: 1.0856e-04
# Epoch 30/50
# 2097/2097 [==============================] - 0s 231us/step - loss: 1.1049e-04 - val_loss: 8.1268e-05
# Epoch 31/50
# 2097/2097 [==============================] - 0s 234us/step - loss: 1.0182e-04 - val_loss: 8.7476e-05
# Epoch 32/50
# 2097/2097 [==============================] - 0s 238us/step - loss: 1.0218e-04 - val_loss: 8.3330e-05
# Epoch 33/50
# 2097/2097 [==============================] - 1s 284us/step - loss: 9.5805e-05 - val_loss: 6.9320e-05
# Epoch 34/50
# 2097/2097 [==============================] - 1s 272us/step - loss: 8.4919e-05 - val_loss: 1.2426e-04
# Epoch 35/50
# 2097/2097 [==============================] - 1s 273us/step - loss: 1.2909e-04 - val_loss: 6.3258e-05
# Epoch 36/50
# 2097/2097 [==============================] - 1s 268us/step - loss: 7.8371e-05 - val_loss: 6.2008e-05
# Epoch 37/50
# 2097/2097 [==============================] - 1s 266us/step - loss: 8.0086e-05 - val_loss: 9.7767e-05
# Epoch 38/50
# 2097/2097 [==============================] - 0s 232us/step - loss: 8.6555e-05 - val_loss: 6.9462e-05
# Epoch 39/50
# 2097/2097 [==============================] - 1s 244us/step - loss: 8.7736e-05 - val_loss: 7.8673e-05
# Epoch 40/50
# 2097/2097 [==============================] - 1s 251us/step - loss: 7.9770e-05 - val_loss: 6.1527e-05
# Epoch 41/50
# 2097/2097 [==============================] - 1s 257us/step - loss: 8.4042e-05 - val_loss: 6.9354e-05
# Epoch 42/50
# 2097/2097 [==============================] - 1s 254us/step - loss: 9.0208e-05 - val_loss: 6.5803e-05
# Epoch 43/50
# 2097/2097 [==============================] - 1s 245us/step - loss: 8.1767e-05 - val_loss: 8.1848e-05
# Epoch 44/50
# 2097/2097 [==============================] - 1s 262us/step - loss: 8.9768e-05 - val_loss: 7.0507e-05
# Epoch 45/50
# 2097/2097 [==============================] - 1s 250us/step - loss: 7.0925e-05 - val_loss: 5.8421e-05
# Epoch 46/50
# 2097/2097 [==============================] - 1s 254us/step - loss: 7.1608e-05 - val_loss: 9.2492e-05
# Epoch 47/50
# 2097/2097 [==============================] - 1s 243us/step - loss: 8.6628e-05 - val_loss: 5.8415e-05
# Epoch 48/50
# 2097/2097 [==============================] - 0s 232us/step - loss: 6.7365e-05 - val_loss: 5.4047e-05
# Epoch 49/50
# 2097/2097 [==============================] - 0s 232us/step - loss: 7.5350e-05 - val_loss: 5.8897e-05
# Epoch 50/50
# 2097/2097 [==============================] - 1s 243us/step - loss: 7.1570e-05 - val_loss: 5.9019e-05

# %%
# evaluate the result
test_mse = model.evaluate(X_test, y_test, verbose=1)
print('\nThe mean squared error (MSE) on the test data set is %.3f over %d test samples.' % (test_mse, len(y_test)))
# Out:
# 245/245 [==============================] - 0s 139us/step
#
# The mean squared error (MSE) on the test data set is 0.000 over 245 test samples.

# %% [markdown]
# ## 测试集验证

# %%
# get the predicted values
predicted_values = model.predict(X_test)
num_test_samples = len(predicted_values)
predicted_values = np.reshape(predicted_values, (num_test_samples,1))

# %%
predicted_values = pd.Series(predicted_values[:, 0], index=vec.index[train_row+seq_len-1:])

# %%
true_values = pd.Series(y_test, index=vec.index[train_row+seq_len-1:])

# %%
# plot the results
fig, ax = plt.subplots(figsize=(16, 9))
ax.plot(true_values + test_mean.reshape(-1), label=u'样本外真实相关性')
ax.plot(predicted_values + test_mean.reshape(-1), label=u'样本外预测相关性')
ax.legend()

# %% [markdown]
# ## 未来相关性预测

# %%
# fut_vec = vec[-seq_len:].tolist()
# fut_vec = (predicted_values + shifted_value)[-seq_len:].tolist()
fut_vec = (predicted_values + test_mean.reshape(-1))[-seq_len:].tolist()
fut_len = 10

# %%
for i in range(fut_len):
    pred_vec = np.array(fut_vec[-seq_len+1:])
    matrix = pred_vec - pred_vec.mean()
#     matrix -= shifted_value
    matrix = np.reshape(matrix, (1, seq_len-1, 1))
    pred = model.predict(matrix)
    print(pred[0][0] + pred_vec.mean())
    fut_vec.append(pred[0][0] + pred_vec.mean())
#     print(pred[0][0])
# Out:
# -0.19347954038652032
# -0.1926577658668471
# -0.19134360817479815
# -0.19010152220830057
# -0.1891003267566081
# -0.18852089213730427
# -0.18842246369147606
# -0.18883705388489092
# -0.1896287044758753
# -0.19074300199581118

# %%
dates = [vec.index[-1] + datetime.timedelta(i) for i in range(0, fut_len + 1)]

# %%
fut_seq = pd.Series(fut_vec[-(fut_len+1):], index=pd.to_datetime(dates))

# %%
# plot the results
fig, ax = plt.subplots(figsize=(25, 10))
x = true_values + test_mean.reshape(-1)
y = predicted_values + test_mean.reshape(-1)
ax.plot(x[x.index >= '2018-01-01'], label=u'样本外真实相关性', linewidth=5)
ax.plot(y[y.index >= '2018-01-01'], label=u'样本外预测相关性', linewidth=5)
ax.plot(fut_seq, label=u'未来相关性预测', color='red', linewidth=5)
ax.set_title(u'股票-债券相关性预测', fontsize=30)
# ax.set_title(u'股票-商品相关性预测', fontsize=30)
# ax.set_title(u'债券-商品相关性预测', fontsize=30)
ax.legend(fontsize=20)

# %%
fig.savefig('../pic/volatility_prediction_stock_bond.png', dpi=200, bbox_inches='tight')
# fig.savefig('../pic/volatility_prediction_stock_commodity.png', dpi=200, bbox_inches='tight')
# fig.savefig('../pic/volatility_prediction_bond_commodity.png', dpi=200, bbox_inches='tight')
