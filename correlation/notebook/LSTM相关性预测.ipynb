# %% [markdown]
# # LSTM相关性预测

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.models import Sequential
import datetime
# %matplotlib inline

# %% [markdown]
# ## 读取波动率序列

# %%
np.random.seed(1234)
seq_len = 20

# %%
fname = '../../risk parity portfolio/data/assets.xlsx'
df = pd.read_excel(fname)
# df.sort_index(inplace=True, ascending=False)
vec = df['AU9999.SGE'].pct_change().rolling(window=243).corr(df['CBA00101.CS'].pct_change())
vec = vec[vec.index >= '2009-01-01']
vec.tail()
# Out:
# 2018-11-01    0.125412
# 2018-11-02    0.127592
# 2018-11-05    0.128602
# 2018-11-06    0.133031
# 2018-11-07    0.134312
# dtype: float64

# %%
fig, ax = plt.subplots(figsize=(16, 9))
ax.plot(vec, label=u'相关性')
ax.legend()

# %% [markdown]
# ## 将序列转成矩阵
# 横坐标是样本点的个数，纵坐标是窗口大小

# %%
def series2matrix(vec, seq_len):
    matrix = []
    for i in range(vec.size - seq_len + 1):
        matrix.append(vec[i : i+seq_len])
    return np.array(matrix)

# %%
mat = series2matrix(vec, seq_len)

# %%
fig, ax = plt.subplots(figsize=(16, 9))
ax.plot(mat[:, -1], label=u'相关性')
ax.legend()

# %% [markdown]
# ## 序列预处理

# %%
# shift all data by mean
# shifted_value = mat.mean()
# mat -= shifted_value

# %% [markdown]
# ## 得到训练和测试样本

# %%
# split dataset: 90% for training and 10% for testing
train_row = int(round(0.9 * mat.shape[0]))
train_set = mat[:train_row, :].copy()
train_mean = train_set.mean(axis=1).reshape(-1, 1).copy()
train_set -= train_mean
test_set = mat[train_row:, :].copy()
test_mean = test_set.mean(axis=1).reshape(-1, 1).copy()
test_set -= test_mean

# %%
fig, ax = plt.subplots(figsize=(16, 9))
ax.plot((train_set + train_mean)[:, -1], label=u'相关性')
# ax.plot((test_set + test_mean)[:, -1], label=u'波动率')
ax.legend()

# %%
# shuffle the training set (but do not shuffle the test set)
np.random.shuffle(train_set)
# the training set
X_train = train_set[:, :-1]
# the last column is the true value to compute the mean-squared-error loss
y_train = train_set[:, -1] 
# the test set
X_test = test_set[:, :-1]
y_test = test_set[:, -1]

# %%
# the input to LSTM layer needs to have the shape of (number of samples, the dimension of each element)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (2138, 19, 1)
# (237, 19, 1)

# %% [markdown]
# ## 构建模型

# %%
# build the model
model = Sequential()

# %%
# layer 1: LSTM
model.add(LSTM(input_shape=(None,1), units=50, return_sequences=True))
model.add(Dropout(0.2))

# %%
# layer 2: LSTM
model.add(LSTM(units=100, return_sequences=False))
model.add(Dropout(0.2))

# %%
# layer 3: dense
# linear activation: a(x) = x
model.add(Dense(units=1, activation='linear'))

# %%
# compile the model
model.compile(loss="mse", optimizer="rmsprop")

# %% [markdown]
# ## 训练模型

# %%
# train the model
model.fit(X_train, y_train, batch_size=512, epochs=50, validation_split=0.05, verbose=1)
# Out:
# Train on 2031 samples, validate on 107 samples
# Epoch 1/50
# 2031/2031 [==============================] - 2s 1ms/step - loss: 9.1351e-04 - val_loss: 3.6699e-04
# Epoch 2/50
# 2031/2031 [==============================] - 0s 222us/step - loss: 4.7470e-04 - val_loss: 3.3164e-04
# Epoch 3/50
# 2031/2031 [==============================] - 0s 219us/step - loss: 4.3931e-04 - val_loss: 2.8543e-04
# Epoch 4/50
# 2031/2031 [==============================] - 0s 219us/step - loss: 3.8336e-04 - val_loss: 2.4464e-04
# Epoch 5/50
# 2031/2031 [==============================] - 0s 218us/step - loss: 4.1503e-04 - val_loss: 4.3610e-04
# Epoch 6/50
# 2031/2031 [==============================] - 0s 220us/step - loss: 3.5589e-04 - val_loss: 1.6051e-04
# Epoch 7/50
# 2031/2031 [==============================] - 0s 220us/step - loss: 2.4723e-04 - val_loss: 2.9378e-04
# Epoch 8/50
# 2031/2031 [==============================] - 0s 222us/step - loss: 3.2914e-04 - val_loss: 1.4316e-04
# Epoch 9/50
# 2031/2031 [==============================] - 0s 218us/step - loss: 2.1403e-04 - val_loss: 2.0280e-04
# Epoch 10/50
# 2031/2031 [==============================] - 0s 215us/step - loss: 2.9880e-04 - val_loss: 1.4489e-04
# Epoch 11/50
# 2031/2031 [==============================] - 0s 211us/step - loss: 2.0535e-04 - val_loss: 1.2311e-04
# Epoch 12/50
# 2031/2031 [==============================] - 0s 225us/step - loss: 2.3364e-04 - val_loss: 3.5389e-04
# Epoch 13/50
# 2031/2031 [==============================] - 0s 220us/step - loss: 2.8051e-04 - val_loss: 1.2599e-04
# Epoch 14/50
# 2031/2031 [==============================] - 0s 236us/step - loss: 1.8902e-04 - val_loss: 1.2275e-04
# Epoch 15/50
# 2031/2031 [==============================] - 0s 244us/step - loss: 2.0056e-04 - val_loss: 1.8098e-04
# Epoch 16/50
# 2031/2031 [==============================] - 0s 235us/step - loss: 2.2240e-04 - val_loss: 1.2120e-04
# Epoch 17/50
# 2031/2031 [==============================] - 0s 241us/step - loss: 1.8924e-04 - val_loss: 1.5943e-04
# Epoch 18/50
# 2031/2031 [==============================] - 0s 238us/step - loss: 2.2737e-04 - val_loss: 1.2630e-04
# Epoch 19/50
# 2031/2031 [==============================] - 0s 244us/step - loss: 1.8116e-04 - val_loss: 1.3803e-04
# Epoch 20/50
# 2031/2031 [==============================] - 0s 236us/step - loss: 2.1924e-04 - val_loss: 1.3287e-04
# Epoch 21/50
# 2031/2031 [==============================] - 0s 241us/step - loss: 1.7189e-04 - val_loss: 1.2329e-04
# Epoch 22/50
# 2031/2031 [==============================] - 0s 229us/step - loss: 1.8424e-04 - val_loss: 1.5163e-04
# Epoch 23/50
# 2031/2031 [==============================] - 0s 225us/step - loss: 1.8351e-04 - val_loss: 1.2179e-04
# Epoch 24/50
# 2031/2031 [==============================] - 0s 216us/step - loss: 1.5382e-04 - val_loss: 1.1538e-04
# Epoch 25/50
# 2031/2031 [==============================] - 0s 222us/step - loss: 2.9106e-04 - val_loss: 1.3880e-04
# Epoch 26/50
# 2031/2031 [==============================] - 0s 218us/step - loss: 1.5846e-04 - val_loss: 1.1971e-04
# Epoch 27/50
# 2031/2031 [==============================] - 0s 217us/step - loss: 1.5430e-04 - val_loss: 1.1844e-04
# Epoch 28/50
# 2031/2031 [==============================] - 0s 222us/step - loss: 1.4353e-04 - val_loss: 1.1853e-04
# Epoch 29/50
# 2031/2031 [==============================] - 0s 216us/step - loss: 1.4606e-04 - val_loss: 1.6073e-04
# Epoch 30/50
# 2031/2031 [==============================] - 0s 223us/step - loss: 1.6417e-04 - val_loss: 1.1587e-04
# Epoch 31/50
# 2031/2031 [==============================] - 0s 213us/step - loss: 1.3093e-04 - val_loss: 1.2704e-04
# Epoch 32/50
# 2031/2031 [==============================] - 0s 207us/step - loss: 1.5017e-04 - val_loss: 1.8305e-04
# Epoch 33/50
# 2031/2031 [==============================] - 0s 212us/step - loss: 1.4606e-04 - val_loss: 1.1300e-04
# Epoch 34/50
# 2031/2031 [==============================] - 0s 222us/step - loss: 1.3569e-04 - val_loss: 1.6827e-04
# Epoch 35/50
# 2031/2031 [==============================] - 1s 252us/step - loss: 1.5617e-04 - val_loss: 1.1608e-04
# Epoch 36/50
# 2031/2031 [==============================] - 1s 255us/step - loss: 1.2613e-04 - val_loss: 1.3811e-04
# Epoch 37/50
# 2031/2031 [==============================] - 0s 226us/step - loss: 1.5346e-04 - val_loss: 1.1073e-04
# Epoch 38/50
# 2031/2031 [==============================] - 0s 236us/step - loss: 1.2016e-04 - val_loss: 1.2045e-04
# Epoch 39/50
# 2031/2031 [==============================] - 1s 254us/step - loss: 1.3548e-04 - val_loss: 1.1465e-04
# Epoch 40/50
# 2031/2031 [==============================] - 0s 224us/step - loss: 1.2088e-04 - val_loss: 1.1417e-04
# Epoch 41/50
# 2031/2031 [==============================] - 1s 253us/step - loss: 1.3817e-04 - val_loss: 1.0978e-04
# Epoch 42/50
# 2031/2031 [==============================] - 0s 240us/step - loss: 1.0506e-04 - val_loss: 1.3526e-04
# Epoch 43/50
# 2031/2031 [==============================] - 1s 258us/step - loss: 1.3030e-04 - val_loss: 1.1992e-04
# Epoch 44/50
# 2031/2031 [==============================] - 1s 257us/step - loss: 1.0688e-04 - val_loss: 1.2389e-04
# Epoch 45/50
# 2031/2031 [==============================] - 1s 249us/step - loss: 1.2633e-04 - val_loss: 1.2579e-04
# Epoch 46/50
# 2031/2031 [==============================] - 1s 262us/step - loss: 1.2168e-04 - val_loss: 1.1940e-04
# Epoch 47/50
# 2031/2031 [==============================] - 1s 258us/step - loss: 1.1006e-04 - val_loss: 1.2643e-04
# Epoch 48/50
# 2031/2031 [==============================] - 1s 249us/step - loss: 1.1459e-04 - val_loss: 1.1937e-04
# Epoch 49/50
# 2031/2031 [==============================] - 0s 236us/step - loss: 1.0631e-04 - val_loss: 1.3326e-04
# Epoch 50/50
# 2031/2031 [==============================] - 0s 226us/step - loss: 1.1607e-04 - val_loss: 1.1983e-04

# %%
# evaluate the result
test_mse = model.evaluate(X_test, y_test, verbose=1)
print('\nThe mean squared error (MSE) on the test data set is %.3f over %d test samples.' % (test_mse, len(y_test)))
# Out:
# 237/237 [==============================] - 0s 249us/step
#
# The mean squared error (MSE) on the test data set is 0.000 over 237 test samples.

# %% [markdown]
# ## 测试集验证

# %%
# get the predicted values
predicted_values = model.predict(X_test)
num_test_samples = len(predicted_values)
predicted_values = np.reshape(predicted_values, (num_test_samples,1))

# %%
predicted_values = pd.Series(predicted_values[:, 0], index=vec.index[train_row+seq_len-1:])

# %%
true_values = pd.Series(y_test, index=vec.index[train_row+seq_len-1:])

# %%
# plot the results
fig, ax = plt.subplots(figsize=(16, 9))
ax.plot(true_values + test_mean.reshape(-1), label=u'样本外真实相关性')
ax.plot(predicted_values + test_mean.reshape(-1), label=u'样本外预测相关性')
ax.legend()

# %% [markdown]
# ## 未来相关性预测

# %%
# fut_vec = vec[-seq_len:].tolist()
# fut_vec = (predicted_values + shifted_value)[-seq_len:].tolist()
fut_vec = (predicted_values + test_mean.reshape(-1))[-seq_len:].tolist()
fut_len = 10

# %%
for i in range(fut_len):
    pred_vec = np.array(fut_vec[-seq_len+1:])
    matrix = pred_vec - pred_vec.mean()
#     matrix -= shifted_value
    matrix = np.reshape(matrix, (1, seq_len-1, 1))
    pred = model.predict(matrix)
    print(pred[0][0] + pred_vec.mean())
    fut_vec.append(pred[0][0] + pred_vec.mean())
#     print(pred[0][0])
# Out:
# 0.13731624707553042
# 0.1394138360536755
# 0.14123588944129947
# 0.1427408529453834
# 0.14401827082257815
# 0.1451302823461454
# 0.1461091596477855
# 0.14698667042924604
# 0.14778499897591602
# 0.14850439699752363

# %%
dates = [vec.index[-1] + datetime.timedelta(i) for i in range(0, fut_len + 1)]

# %%
fut_seq = pd.Series(fut_vec[-(fut_len+1):], index=pd.to_datetime(dates))

# %%
# plot the results
fig, ax = plt.subplots(figsize=(25, 10))
x = true_values + test_mean.reshape(-1)
y = predicted_values + test_mean.reshape(-1)
ax.plot(x[x.index >= '2018-01-01'], label=u'样本外真实相关性', linewidth=5)
ax.plot(y[y.index >= '2018-01-01'], label=u'样本外预测相关性', linewidth=5)
ax.plot(fut_seq, label=u'未来相关性预测', color='red', linewidth=5)
# ax.set_title(u'股票-债券相关性预测', fontsize=30)
# ax.set_title(u'股票-商品相关性预测', fontsize=30)
ax.set_title(u'债券-商品相关性预测', fontsize=30)
ax.legend(fontsize=20)

# %%
# fig.savefig('../pic/volatility_prediction_stock_bond.png', dpi=200, bbox_inches='tight')
# fig.savefig('../pic/volatility_prediction_stock_commodity.png', dpi=200, bbox_inches='tight')
fig.savefig('../pic/volatility_prediction_bond_commodity.png', dpi=200, bbox_inches='tight')
