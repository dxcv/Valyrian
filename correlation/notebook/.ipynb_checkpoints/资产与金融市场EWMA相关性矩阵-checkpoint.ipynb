# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from WindPy import w
# %matplotlib inline

# %%
w.start()
# Out:
# .ErrorCode=0
# .Data=[Already conntected!]

# %% [markdown]
# ## 获取起始日期

# %%
today = datetime.datetime.today()

# %%
today.strftime('%Y-%m-%d')
# Out:
# '2019-02-18'

# %%
start_date = today - datetime.timedelta(365) # 最近1年

# %%
start_date.strftime('%Y-%m-%d')
# Out:
# '2018-02-18'

# %% [markdown]
# ## 获取数据

# %%
df = pd.read_excel(u'../data/资产与宏观变量.xlsx')

# %%
df
# Out:
#    Variables       Name       Assets
# 0  USDCNH.FX     美元兑人民币    000300.SH
# 1   S0059749   10Y国债收益率    000905.SH
# 2   M0017142  3M SHIBOR    881001.WI
# 3   S0059766  AA级企业债收益率  CBA00602.CS
# 4   G1122652      股票波动率  CBA02002.CS
# 5     SPX.GI      标普500   AU9999.SGE
# 6   G0000891   10Y美债收益率       HSI.HI
# 7   G8324466      A股市盈率          NaN

# %%
var2name = {k: v for k, v in zip(df['Variables'], df['Name'])}

# %%
data = w.wsd(df['Assets'].tolist()[:7], 'close', start_date, today)

# %%
price = pd.DataFrame(np.array(data.Data).T, index=data.Times, columns=data.Codes)

# %%
price.head()
# Out:
#             000300.SH  000905.SH  881001.WI  CBA00602.CS  CBA02002.CS  \
# 2018-02-22  4052.7332  5875.7272  4337.2092     112.8970      77.6605
# 2018-02-23  4071.0889  5897.6765  4354.7585     112.9421      77.6606
# 2018-02-26  4118.4186  6029.6795  4426.4939     113.1793      77.7041
# 2018-02-27  4058.9806  6010.5573  4394.6736     113.2963      77.7361
# 2018-02-28  4023.6415  6023.6770  4380.6025     113.3765      77.7766
#
#             AU9999.SGE    HSI.HI
# 2018-02-22      271.36  30965.68
# 2018-02-23      271.96  31267.17
# 2018-02-26      273.60  31498.60
# 2018-02-27      272.36  31268.66
# 2018-02-28      270.30  30844.72

# %%
price.tail()
# Out:
#             000300.SH  000905.SH  881001.WI  CBA00602.CS  CBA02002.CS  \
# 2019-02-12  3330.3353  4439.4850  3510.0015     118.9386      80.0476
# 2019-02-13  3397.0276  4512.4088  3575.5265     118.9720      80.0665
# 2019-02-14  3402.1403  4532.1699  3586.3165     118.9292      80.0897
# 2019-02-15  3338.7047  4502.7348  3547.7599     118.9025      80.1022
# 2019-02-18  3338.7047  4502.7348  3547.7599     118.9025      80.1022
#
#             AU9999.SGE    HSI.HI
# 2019-02-12      287.80  28171.33
# 2019-02-13      287.07  28497.59
# 2019-02-14      286.50  28432.05
# 2019-02-15      288.41  27900.84
# 2019-02-18      288.41  27900.84

# %%
market_variables = [x for x in df['Variables'] if str(x).find('.') != -1]
economic_variables = [x for x in df['Variables'] if str(x).find('.') == -1 and str(x) != 'nan']

# %%
market_variables
# Out:
# [u'USDCNH.FX', u'SPX.GI']

# %%
economic_variables
# Out:
# [u'S0059749', u'M0017142', u'S0059766', u'G1122652', u'G0000891', u'G8324466']

# %%
data = w.wsd(market_variables, 'close', start_date, today)

# %%
market_df = pd.DataFrame(np.array(data.Data).T, index=data.Times, columns=[var2name[x] for x in market_variables])

# %%
market_df.tail()
# Out:
#             美元兑人民币    标普500
# 2019-02-12  6.7737  2744.73
# 2019-02-13  6.7833  2753.03
# 2019-02-14  6.7791  2745.73
# 2019-02-15  6.7703  2775.60
# 2019-02-18  6.7703  2775.60

# %%
market_nav = (1+market_df.pct_change()).cumprod()

# %%
market_nav.plot(figsize=(16, 9))

# %%
data = w.edb(economic_variables, start_date, today)

# %%
economic_df = pd.DataFrame(np.array(data.Data).T, index=data.Times, columns=[var2name[x] for x in economic_variables])

# %%
economic_df.head()
# Out:
#             10Y国债收益率  3M SHIBOR  AA级企业债收益率  股票波动率  10Y美债收益率  A股市盈率
# 2018-02-20       NaN        NaN        NaN  27.85      2.88    NaN
# 2018-02-21       NaN        NaN        NaN  29.26      2.94    NaN
# 2018-02-22    3.8752     4.7054     6.0835  28.08      2.92  18.11
# 2018-02-23    3.8702     4.7076     6.0833  27.43      2.88  18.22
# 2018-02-24    3.8652     4.7078     6.0751    NaN       NaN    NaN

# %%
economic_df[u'信用利差'] = economic_df[u'AA级企业债收益率'] - economic_df[u'10Y国债收益率']

# %%
del economic_df[u'AA级企业债收益率']

# %%
economic_nav = (1 + economic_df.pct_change()).cumprod().fillna(method='ffill')

# %%
economic_nav.plot(figsize=(16, 9))

# %%
variable_df = market_nav.join(economic_nav)

# %%
variable_df.iloc[0] = 1

# %%
variable_df.plot(figsize=(16, 9))

# %%
variable_df.to_excel('../data/variables.xlsx')

# %% [markdown]
# ## 初始化表格

# %%
ret_df = pd.DataFrame()

# %%
ret_df[u'成长股'] = price['000905.SH'].pct_change()
ret_df[u'价值股'] = price['000300.SH'].pct_change()
ret_df[u'港股'] = price['HSI.HI'].pct_change()
ret_df[u'黄金'] = price['AU9999.SGE'].pct_change()
ret_df[u'国债'] = price['CBA00602.CS'].pct_change()
ret_df[u'信用债'] = price['CBA02002.CS'].pct_change()

# %%
nav = (1 + ret_df).cumprod()

# %%
nav.iloc[0] = 1

# %%
nav.plot(figsize=(16, 9))

# %%
nav.to_excel(u'../data/nav.xlsx')

# %% [markdown]
# ## 生成EWMA相关性矩阵

# %%
cor_df = pd.DataFrame(index= ret_df.columns, 
                      columns=market_df.columns.tolist() + economic_df.columns.tolist())

# %%
for asset in cor_df.index:
    for var in cor_df.columns:
        if var in market_df.columns:
            s, t = (1+ret_df[asset]).cumprod(), (1+market_df[var].pct_change()).cumprod()
            corr = s.ewm(alpha=0.02, ignore_na=True, adjust=True).corr(t)
            cor_df.loc[asset, var] = corr[-1]
        elif var in economic_df.columns:
            s, t = (1+ret_df[asset]).cumprod(), (1+economic_df[var].pct_change()).cumprod()
            corr = s.ewm(alpha=0.02, ignore_na=True, adjust=True).corr(t)
            cor_df.loc[asset, var] = corr[-1]

# %%
cor_df
# Out:
#         美元兑人民币     标普500   10Y国债收益率 3M SHIBOR     股票波动率  10Y美债收益率     A股市盈率  \
# 成长股  -0.619207  0.474791   0.567581  0.607155 -0.216099  0.209861  0.910999
# 价值股  -0.667002  0.595028   0.421793  0.454105 -0.323609  0.171726  0.940558
# 港股    -0.82462   0.47314  0.0177257  0.309591 -0.702465 -0.238699  0.761354
# 黄金   -0.106468 -0.545588  -0.912637 -0.225273 -0.268628 -0.729042 -0.414741
# 国债  -0.0405664 -0.528982  -0.989101 -0.276814 -0.330894 -0.764576 -0.489581
# 信用债  0.0257366 -0.416692  -0.957042 -0.464845 -0.313718  -0.66606 -0.491794
#
#          信用利差
# 成长股  0.253765
# 价值股   0.38636
# 港股   0.474801
# 黄金  -0.109177
# 国债  -0.118611
# 信用债 -0.168952

# %%
cor_df.to_excel(u'../data/ewma_cor.xlsx')

# %%
# cor_df[cor_df.abs() < 0.1] = 0

# %%
cor_df
# Out:
#         美元兑人民币     标普500   10Y国债收益率 3M SHIBOR     股票波动率  10Y美债收益率     A股市盈率  \
# 成长股  -0.619207  0.474791   0.567581  0.607155 -0.216099  0.209861  0.910999
# 价值股  -0.667002  0.595028   0.421793  0.454105 -0.323609  0.171726  0.940558
# 港股    -0.82462   0.47314  0.0177257  0.309591 -0.702465 -0.238699  0.761354
# 黄金   -0.106468 -0.545588  -0.912637 -0.225273 -0.268628 -0.729042 -0.414741
# 国债  -0.0405664 -0.528982  -0.989101 -0.276814 -0.330894 -0.764576 -0.489581
# 信用债  0.0257366 -0.416692  -0.957042 -0.464845 -0.313718  -0.66606 -0.491794
#
#          信用利差
# 成长股  0.253765
# 价值股   0.38636
# 港股   0.474801
# 黄金  -0.109177
# 国债  -0.118611
# 信用债 -0.168952

# %% [markdown]
# ## 计算变量的trend

# %%
trend = {}
for var in cor_df.columns:
    if var in market_df.columns:
        t = market_df[var]
    elif var in economic_df.columns:
        t = economic_df[var]
    ret = t.pct_change()[-60:]
    up, down = ret[ret > 0].sum(), -ret[ret < 0].sum()
    if up > down:
        trend[var] = up / down
    else:
        trend[var] = -down / up

# %%
for k, v in trend.iteritems():
    print k, v
# Out:
# 标普500 1.0803250434155052
# 股票波动率 -1.4537891382246546
# 3M SHIBOR -2.27931064896445
# 美元兑人民币 -1.3888413843235563
# 信用利差 1.2909942273249002
# 10Y国债收益率 -1.9730699741958466
# A股市盈率 1.0492773181628998
# 10Y美债收益率 -1.5560258140706795

# %% [markdown]
# # 综合得到Score Board

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
board = pd.DataFrame(index=cor_df.index, columns=cor_df.columns)
for var in cor_df.columns:
    x = cor_df[var] * trend[var]
    board[var] = sigmoid(x.astype(np.float32))

# %%
trend_df = pd.DataFrame(trend, index=[u'变量趋势'])

# %%
board = trend_df.append(board)

# %%
board = board[cor_df.columns]

# %%
board
# Out:
#         美元兑人民币     标普500  10Y国债收益率  3M SHIBOR     股票波动率  10Y美债收益率     A股市盈率  \
# 变量趋势 -1.388841  1.080325 -1.973070  -2.279311 -1.453789 -1.556026  1.049277
# 成长股   0.702657  0.625493  0.246034   0.200384  0.577901  0.419081  0.722298
# 价值股   0.716336  0.655392  0.303174   0.262107  0.615492  0.433592  0.728477
# 港股    0.758645  0.625075  0.491257   0.330560  0.735213  0.591802  0.689733
# 黄金    0.536900  0.356770  0.858234   0.625619  0.596410  0.756651  0.392891
# 国债    0.514081  0.360897  0.875617   0.652704  0.617996  0.766687  0.374325
# 信用债   0.491065  0.389322  0.868563   0.742600  0.612084  0.738156  0.373781
#
#           信用利差
# 变量趋势  1.290994
# 成长股   0.581178
# 价值股   0.622175
# 港股    0.648617
# 黄金    0.464822
# 国债    0.461793
# 信用债   0.445686

# %%
board.to_excel(u'../data/dashboard.xlsx')
